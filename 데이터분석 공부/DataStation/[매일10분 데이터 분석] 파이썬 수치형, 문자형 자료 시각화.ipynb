# %%
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.rc('font', family='Malgun Gothic')

# %%
df1=pd.read_csv('Data03.csv')
df1.head()
# Out:
#          id type_of_contract type_of_contract2 channel    datetime  Term  \
# 0  66758234               렌탈            Normal  서비스 방문  2019-10-20    60
# 1  66755948               렌탈  Extension_Rental  서비스 방문  2019-10-20    60
# 2  66756657               렌탈            Normal  홈쇼핑/방송  2019-10-20    60
# 3  66423450              멤버십               TAS   렌탈재계약  2019-10-20    12
# 4  66423204              멤버십               TAS   렌탈재계약  2019-10-20    12
#
#   payment_type product  amount state  overdue_count overdue  credit rating  \
# 0          CMS      K1   96900  계약확정              0      없음            9.0
# 1         카드이체      K1  102900  계약확정              0      없음            2.0
# 2          CMS      K1   96900  계약확정              0      없음            8.0
# 3          CMS      K1   66900  계약확정              0      없음            5.0
# 4          CMS      K1   66900  해약확정             12      있음            8.0
#
#     bank cancellation   age  Mileage
# 0  새마을금고           정상  43.0   1862.0
# 1   현대카드           정상  62.0   2532.0
# 2   우리은행           정상  60.0   2363.0
# 3   농협은행           정상  60.0   2449.0
# 4   농협은행           해약  51.0   1942.0

# %% [markdown]
# ## 다변수
# * X: 연속 / Y: 연속
#     - 산점도, 회귀선, 상관분석

# %% [markdown]
# ### 산점도

# %%
sns.scatterplot(data=df1, x='age', y='Mileage', hue='type_of_contract')
# Out:
# <AxesSubplot:xlabel='age', ylabel='Mileage'>

# %%
sns.scatterplot(data=df1, x='age', y='Mileage', hue='type_of_contract', size='Term')
# Out:
# <AxesSubplot:xlabel='age', ylabel='Mileage'>

# %%
sns.lmplot(data=df1, x='age', y='Mileage', hue='product')

# %%
sns.jointplot(data=df1, x='age', y='amount')

# %%
sns.pairplot(df1)

# %%
sns.pairplot(df1[['age', 'Mileage','amount','product']], hue='product')

# %%
df1.corr() #상관관계 -1~1, 1로 갈수록 양의 상관관계, -1로 갈수록 음의 상관관계

# %% [markdown]
# - x: 범주형, y: 연속형
#     - Barplot / Boxplot

# %%
df1.head()
# Out:
#          id type_of_contract type_of_contract2 channel    datetime  Term  \
# 0  66758234               렌탈            Normal  서비스 방문  2019-10-20    60
# 1  66755948               렌탈  Extension_Rental  서비스 방문  2019-10-20    60
# 2  66756657               렌탈            Normal  홈쇼핑/방송  2019-10-20    60
# 3  66423450              멤버십               TAS   렌탈재계약  2019-10-20    12
# 4  66423204              멤버십               TAS   렌탈재계약  2019-10-20    12
#
#   payment_type product  amount state  overdue_count overdue  credit rating  \
# 0          CMS      K1   96900  계약확정              0      없음            9.0
# 1         카드이체      K1  102900  계약확정              0      없음            2.0
# 2          CMS      K1   96900  계약확정              0      없음            8.0
# 3          CMS      K1   66900  계약확정              0      없음            5.0
# 4          CMS      K1   66900  해약확정             12      있음            8.0
#
#     bank cancellation   age  Mileage
# 0  새마을금고           정상  43.0   1862.0
# 1   현대카드           정상  62.0   2532.0
# 2   우리은행           정상  60.0   2363.0
# 3   농협은행           정상  60.0   2449.0
# 4   농협은행           해약  51.0   1942.0

# %%
p1 = pd.pivot_table(data=df1, index='channel', values='amount', aggfunc='sum')
p1.sort_values(by='amount', ascending=False).head(10)
top_list = p1.sort_values(by='amount', ascending=False).head(5).index.tolist()

# %%
df1['channel'].value_counts()
# Out:
# 서비스 방문     15186
# 홈쇼핑/방송     12977
# 렌탈총판        5544
# R관리방판       4727
# 하이마트        3227
# 영업방판        3039
# 렌탈재계약       2193
# 일반          1232
# 전자랜드        1205
# R빌리미         560
# 이마트          265
# 홈플러스         225
# R인터넷         198
# R유통사         188
# 홈쇼핑/인터넷      177
# R렌탈운영        120
# R농협          119
# R농협인터넷몰       83
# R법인그룹         20
# R법인           19
# Name: channel, dtype: int64

# %%
sns.barplot(data=df1, x='channel', y='amount', order=top_list) #평균
# Out:
# <AxesSubplot:xlabel='channel', ylabel='amount'>

# %%
sns.barplot(data=df1, x='channel', y='amount', order=top_list, ci=None, hue='type_of_contract') #평균
# Out:
# <AxesSubplot:xlabel='channel', ylabel='amount'>

# %%
sns.barplot(data=df1, x='channel', y='amount', order=top_list, estimator=sum)
# Out:
# <AxesSubplot:xlabel='channel', ylabel='amount'>

# %%
# %matplotlib inline

# %%
# %matplotlib tk

# %%
sns.boxplot(data=df1, x='channel', y='amount', order=top_list)
# Out:
# <AxesSubplot:xlabel='channel', ylabel='amount'>
